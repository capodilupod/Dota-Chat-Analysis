# %%
import requests
import pandas as pd
import numpy as np
from time import sleep
import json
import urllib

start_match = 3548935820
end_match = 3545635820
base_url = "https://api.opendota.com/api/"

current_match = start_match

final_data = []
while current_match > end_match:
    # try to get batch of 100 matches
    try:
        response = requests.get(base_url + "publicMatches?less_than_match_id=" + str(current_match))
    except (urllib.URLError, ssl.SSLError) as error:
        time.sleep(1)
        current_match -= 1
        continue
    
    # from 100 matches, get the chat data
    try: 
        responses = response.json()
        current_match = responses[-1]['match_id']
    except (ValueError, KeyError) as error:
        current_match -= 1
        continue
        
    if len(responses) > 0:
        for response in responses: 
            try:
                match = requests.get(base_url + "matches/" + str(response['match_id']))
                ch = match.json()["chat"]
            except ValueError as e:
                print (e)
            except KeyError as e:
                print(e)
            if ch is not None:
                chat = [x for x in ch if x['type'] == "chat"]
                radiant = []
                dire = []
                if len(chat) > 0:
                    for entry in chat:
                        try:
                            if entry['player_slot'] < 5:
                                radiant.append((entry['key'], entry['time']))
                            else:
                                dire.append((entry['key'], entry['time']))
                        except:
                            continue
                    try:
                        final_data.append((response['match_id'], radiant, dire, match.json()["radiant_win"]))
                        print(response['match_id'])
                    except KeyError as e:
                        continue
# Out:
# 3548935602
# 3548935303
# 3548935205
# 3548935007
# 3548934300
# 3548934208
# 3548934005
# 3548933903
# 3548933807
# 3548933800
# 3548933707
# 3548933502
# 3548933305
# 3548932801
# 3548932604
# 3548932107
# 3548931707
# 3548931508
# 3548931504
# 3548931208
# 3548931007
# 3548930906
# 3548930703
# 3548930505
# 3548930407
# 3548929603
# 3548929509
# 3548929205
# 3548928807
# 3548928606
# 3548928403
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 3548926709
# 3548926202
# 3548926009
# 3548926001
# 3548925607
# 3548925604
# 3548925500
# 3548925303
# 3548924806
# 3548923702
# 3548923508
# 3548923503
# 3548923409
# 3548923302
# 3548923205
# 3548922909
# 3548922809
# 3548922605
# 3548922604
# 3548922308
# 3548922307
# 3548921808
# 3548921801
# 3548921704
# 3548921701
# 3548921402
# 3548921204
# 3548921105
# 3548921104
# 3548920901
# 3548920105
# 3548920102
# 3548920101
# 3548919807
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 'chat'
# 3548917109
# 3548916706
# 3548916309
# 3548915905
# 3548915609
# 3548915102
# 3548914703
# 3548914500
# 3548914402
# 3548913801
# 3548913602
# 3548913403
# 3548912808
# 3548912803
# 3548912105
# 3548911905
# 3548911306
# 3548911303
# 3548911302
# 3548911300
# 3548911209
# 3548911206
# 3548911203
# 3548911007
# 3548911005
# 3548911004
# 3548911003
# 3548910901
# 3548910306
# 3548910007
# 3548910005
# 3548909806
# 3548909507
# 3548909105
# 3548908802
# 3548908609
# 'chat'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-baf077cca6d7> in <module>()
#      52                         except:
#      53                             continue
# ---> 54                     final_data.append((response['match_id'], radiant, dire, match.json()["radiant_win"]))
#      55                     print(response['match_id'])
#      56
#
# KeyError: 'radiant_win'

# %%
len(final_data)
# Out:
# 755

# %%
final_data = pd.DataFrame(final_data)
final_data.columns = ['Match Id', 'Radiant Chat', 'Dire Chat', 'Radiant Win']

# %%
final_data.head()
# Out:
#      Match Id                                       Radiant Chat  \
# 0  3545935700  [(бля, -60), (ty, 639), (изим, 2139), (гг, 217...
# 1  3545935608  [(ty, -9), (ty), 4), (END, 305), (ez mid tinke...
# 2  3545935307  [(glgl, -66), (Fck off man, 354), (SAD, 2535),...
# 3  3545934408  [(que chucha pasa concahtaumdre !, 3281), (ese...
# 4  3545933900  [(haha, 317), (haha, 374), (haha, 537), (haha,...
#
#                                            Dire Chat  Radiant Win
# 0                                       [(uu, 2175)]         True
# 1  [(gl tinker, -12), (wp last game btw, -3), (w8...         True
# 2  [(HFHF, -74), (LEL, 360), (Ahaha, 2235), (LEL,...        False
# 3                                                 []         True
# 4  [(HAHA, 376), (fuck off, 388), (Gg, 422), (gg,...         True
